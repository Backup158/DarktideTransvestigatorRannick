# %%
import pandas as pd
import re

# %%
df = pd.read_csv("Darktide Localization Strings - 1.8.0-b552265.csv")

# %%
display(df)
# Out:
#                               Internal Value  \
# 0                      loc_abhuman_condition
# 1              loc_abhuman_event_description
# 2                     loc_abhuman_event_name
# 3                   loc_ability_frag_grenade
# 4       loc_ability_frag_grenade_description
# ...                                      ...
# 101987                      loc_zone_transit
# 101988                         loc_zone_void
# 101989                    loc_zone_watertown
# 101990                           loc_zoom_in
# 101991                          loc_zoom_out
#
#                                           EN Localization
# 0       Complete missions featuring the Brute Conscrip...
# 1       The Traitorous 6th seem to have conscripted Og...
# 2                                       The Waking Giants
# 3                                            Frag Grenade
# 4       Fragmentation grenade that explodes after a sh...
# ...                                                   ...
# 101987             Transit Hub HL-16-11, "Chasm Terminus"
# 101988                    Inter-Zone Void Sector Omega-12
# 101989                   Habzone HL-18-66,  "The Torrent"
# 101990                                            Zoom In
# 101991                                           Zoom Out
#
# [101992 rows x 2 columns]

# %%
# Using open() function
file_path = 'localization_ids_to_use.txt'

# Open the file in write mode
with open(file_path, 'w') as file:
    for i in range(len(df)):
        string_to_search = df["EN Localization"][i]
        if not isinstance(string_to_search, str):
            continue
        
        if re.search("Interrogator Rannick", string_to_search):
            file.write(df["Internal Value"][i] + '\n')
            print()
